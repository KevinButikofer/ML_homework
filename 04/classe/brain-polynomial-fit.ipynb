# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
data = pd.read_csv('x02.csv', names=['gender', 'age', 'head_size', 'brain_weight'])
x = data['brain_weight'].values * 1.0
y = data['head_size'].values * 1.0

# %%
plt.scatter(x,y)

# %%
plt.hist(x, edgecolor='black')
# Out:
# (array([ 3.,  9., 20., 45., 53., 55., 27., 12.,  8.,  5.]),
#  array([ 955., 1023., 1091., 1159., 1227., 1295., 1363., 1431., 1499.,
#         1567., 1635.]),
#  <a list of 10 Patch objects>)

# %%
coef_deg1 = np.polyfit(x, y, deg=1)
coef_deg2 = np.polyfit(x, y, deg=2)
h1 = np.poly1d(coef_deg1)
h2 = np.poly1d(coef_deg2)

# %%
plt.scatter(x,y)
new_x = np.linspace(1000, 1600, 200)
plt.plot(new_x, h1(new_x), color='red')
plt.plot(new_x, h2(new_x), color='green')
# Out:
# [1000.         1003.01507538 1006.03015075 1009.04522613 1012.06030151
#  1015.07537688 1018.09045226 1021.10552764 1024.12060302 1027.13567839
#  1030.15075377 1033.16582915 1036.18090452 1039.1959799  1042.21105528
#  1045.22613065 1048.24120603 1051.25628141 1054.27135678 1057.28643216
#  1060.30150754 1063.31658291 1066.33165829 1069.34673367 1072.36180905
#  1075.37688442 1078.3919598  1081.40703518 1084.42211055 1087.43718593
#  1090.45226131 1093.46733668 1096.48241206 1099.49748744 1102.51256281
#  1105.52763819 1108.54271357 1111.55778894 1114.57286432 1117.5879397
#  1120.60301508 1123.61809045 1126.63316583 1129.64824121 1132.66331658
#  1135.67839196 1138.69346734 1141.70854271 1144.72361809 1147.73869347
#  1150.75376884 1153.76884422 1156.7839196  1159.79899497 1162.81407035
#  1165.82914573 1168.84422111 1171.85929648 1174.87437186 1177.88944724
#  1180.90452261 1183.91959799 1186.93467337 1189.94974874 1192.96482412
#  1195.9798995  1198.99497487 1202.01005025 1205.02512563 1208.04020101
#  1211.05527638 1214.07035176 1217.08542714 1220.10050251 1223.11557789
#  1226.13065327 1229.14572864 1232.16080402 1235.1758794  1238.19095477
#  1241.20603015 1244.22110553 1247.2361809  1250.25125628 1253.26633166
#  1256.28140704 1259.29648241 1262.31155779 1265.32663317 1268.34170854
#  1271.35678392 1274.3718593  1277.38693467 1280.40201005 1283.41708543
#  1286.4321608  1289.44723618 1292.46231156 1295.47738693 1298.49246231
#  1301.50753769 1304.52261307 1307.53768844 1310.55276382 1313.5678392
#  1316.58291457 1319.59798995 1322.61306533 1325.6281407  1328.64321608
#  1331.65829146 1334.67336683 1337.68844221 1340.70351759 1343.71859296
#  1346.73366834 1349.74874372 1352.7638191  1355.77889447 1358.79396985
#  1361.80904523 1364.8241206  1367.83919598 1370.85427136 1373.86934673
#  1376.88442211 1379.89949749 1382.91457286 1385.92964824 1388.94472362
#  1391.95979899 1394.97487437 1397.98994975 1401.00502513 1404.0201005
#  1407.03517588 1410.05025126 1413.06532663 1416.08040201 1419.09547739
#  1422.11055276 1425.12562814 1428.14070352 1431.15577889 1434.17085427
#  1437.18592965 1440.20100503 1443.2160804  1446.23115578 1449.24623116
#  1452.26130653 1455.27638191 1458.29145729 1461.30653266 1464.32160804
#  1467.33668342 1470.35175879 1473.36683417 1476.38190955 1479.39698492
#  1482.4120603  1485.42713568 1488.44221106 1491.45728643 1494.47236181
#  1497.48743719 1500.50251256 1503.51758794 1506.53266332 1509.54773869
#  1512.56281407 1515.57788945 1518.59296482 1521.6080402  1524.62311558
#  1527.63819095 1530.65326633 1533.66834171 1536.68341709 1539.69849246
#  1542.71356784 1545.72864322 1548.74371859 1551.75879397 1554.77386935
#  1557.78894472 1560.8040201  1563.81909548 1566.83417085 1569.84924623
#  1572.86432161 1575.87939698 1578.89447236 1581.90954774 1584.92462312
#  1587.93969849 1590.95477387 1593.96984925 1596.98492462 1600.        ]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-21da0ca69659> in <module>
#       2 new_x = np.linspace(1000, 1600, 200)
#       3 print(new_x)
# ----> 4 plt.plot(new_x, h1(new_x), color='red')
#       5 plt.plot(new_x, h2(new_x), color='green')
#
# NameError: name 'h1' is not defined
